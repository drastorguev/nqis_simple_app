# %%
import pandas as pd

# %%
url = 'https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_20.zip'


pd.read_csv(url)
# Out:
#      Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0           283469269                283469252.0                  IR
# 1           283469270                283469252.0                  IR
# 2           283469268                        NaN                  IR
# 3           283469263                        NaN                  IR
# 4           283469262                        NaN                  IR
# ..                ...                        ...                 ...
# 213         283468264                283468210.0                  IR
# 214         283468265                283468177.0                  IR
# 215         283468266                283468177.0                  IR
# 216         283468267                283468210.0                  IR
# 217         283468268                283468210.0                  IR
#
#                                 Product ID   Action Transaction Type  \
# 0           InterestRate:IRSwap:FixedFloat   CANCEL            Trade
# 1           InterestRate:IRSwap:FixedFloat  CORRECT            Trade
# 2    InterestRate:CrossCurrency:FixedFloat      NEW        Amendment
# 3                  InterestRate:IRSwap:OIS      NEW            Trade
# 4           InterestRate:IRSwap:FixedFloat      NEW            Trade
# ..                                     ...      ...              ...
# 213         InterestRate:IRSwap:FixedFloat  CORRECT            Trade
# 214                InterestRate:IRSwap:OIS   CANCEL            Trade
# 215                InterestRate:IRSwap:OIS  CORRECT            Trade
# 216         InterestRate:IRSwap:FixedFloat   CANCEL            Trade
# 217         InterestRate:IRSwap:FixedFloat  CORRECT            Trade
#
#     Block Trade Election Indicator Cleared  \
# 0                                N       C
# 1                                N       C
# 2                                Y       U
# 3                                N       C
# 4                                N       C
# ..                             ...     ...
# 213                              N       U
# 214                              N       U
# 215                              N       U
# 216                              N       U
# 217                              N       U
#
#     Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                         NaN        ACT/365.FIXED  ...
# 1                                         NaN        ACT/365.FIXED  ...
# 2                                         NaN               30/360  ...
# 3                                           N        ACT/365.FIXED  ...
# 4                                         NaN        ACT/365.FIXED  ...
# ..                                        ...                  ...  ...
# 213                                       NaN              ACT/360  ...
# 214                                       NaN              ACT/360  ...
# 215                                       NaN              ACT/360  ...
# 216                                       NaN              ACT/360  ...
# 217                                       NaN              ACT/360  ...
#
#     Strike Price Currency    Underlying Asset ID Underlying Asset ID Type  \
# 0                     NaN                  FIXED                      NaN
# 1                     NaN                  FIXED                      NaN
# 2                     NaN                  FIXED                      NaN
# 3                     NaN  JPY-TONA-OIS-COMPOUND                      NaN
# 4                     NaN                  FIXED                      NaN
# ..                    ...                    ...                      ...
# 213                   NaN          USD-LIBOR-BBA                      NaN
# 214                   NaN      USD-SOFR-COMPOUND                      NaN
# 215                   NaN      USD-SOFR-COMPOUND                      NaN
# 216                   NaN          USD-LIBOR-BBA                      NaN
# 217                   NaN          USD-LIBOR-BBA                      NaN
#
#      Underlying Asset Name  Leg 1 - Commodity Instrument ID  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# ..                     ...                              ...
# 213                    NaN                              NaN
# 214                    NaN                              NaN
# 215                    NaN                              NaN
# 216                    NaN                              NaN
# 217                    NaN                              NaN
#
#     Leg 2 - Commodity Instrument ID Option Type Option Style  \
# 0                               NaN         NaN          NaN
# 1                               NaN         NaN          NaN
# 2                               NaN         NaN          NaN
# 3                               NaN         NaN          NaN
# 4                               NaN         NaN          NaN
# ..                              ...         ...          ...
# 213                             NaN         NaN          NaN
# 214                             NaN         NaN          NaN
# 215                             NaN         NaN          NaN
# 216                             NaN         NaN          NaN
# 217                             NaN         NaN          NaN
#
#      Execution Venue Type  Collateralization Type
# 0                     OFF                     NaN
# 1                     OFF                     NaN
# 2                     OFF                     NaN
# 3                      ON                     NaN
# 4                     OFF                     NaN
# ..                    ...                     ...
# 213                   OFF                     NaN
# 214                   OFF                     NaN
# 215                   OFF                     NaN
# 216                   OFF                     NaN
# 217                   OFF                     NaN
#
# [218 rows x 69 columns]

# %%
import requests
from bs4 import BeautifulSoup

url_list = 'https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES.HTML?_=1645469103343'
list_tds = BeautifulSoup(requests.get(url_list).text).find_all("td", class_="s1", align="left")
list_urls = [x.find('a').get('href') for x in list_tds]
file_names = [x.split('/')[-1] for x in list_urls]
file_names
# Out:
# ['CFTC_CUMULATIVE_RATES_2022_02_22.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_21.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_20.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_19.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_18.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_17.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_16.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_15.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_14.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_13.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_12.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_11.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_10.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_09.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_08.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_07.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_06.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_05.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_04.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_03.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_02.zip',
#  'CFTC_CUMULATIVE_RATES_2022_02_01.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_31.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_30.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_29.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_28.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_27.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_26.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_25.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_24.zip',
#  'CFTC_CUMULATIVE_RATES_2022_01_23.zip']

# %%
s3_url_begin = 'https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/'

# %%
import time
df_raw_list = []
for f_n in file_names:
    print('Downloading file: ', f_n)
    print(s3_url_begin + f_n)
    df_temp = pd.read_csv(s3_url_begin + f_n)
    df_raw_list.append(df_temp)
    time.sleep(1)
    
raw_df_master = pd.concat(df_raw_list)
raw_df_master.head(5)
# Out:
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_22.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_22.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (11,17,38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_21.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_21.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_20.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_20.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_19.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_19.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_18.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_18.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_17.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_17.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_16.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_16.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_15.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_15.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24,48,49,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_14.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_14.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24,38,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_13.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_13.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_12.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_12.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_11.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_11.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_10.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_10.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_09.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_09.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (23,48,49,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_08.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_08.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24,38,46,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_07.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_07.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_06.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_06.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_05.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_05.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_04.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_04.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_03.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_03.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_02.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_02.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_02_01.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_02_01.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (8,11,17,38,39,40,48,49,52,53,59,62,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_31.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_31.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_30.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_30.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_29.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_29.zip
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_28.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_28.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24,38,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_27.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_27.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (24,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_26.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_26.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (11,17,48,49,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_25.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_25.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (17,24,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_24.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_24.zip
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/518598831.py:6: DtypeWarning: Columns (48,49,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(s3_url_begin + f_n)
# Downloading file:  CFTC_CUMULATIVE_RATES_2022_01_23.zip
# https://kgc0418-tdw-data-0.s3.amazonaws.com/cftc/eod/CFTC_CUMULATIVE_RATES_2022_01_23.zip
#    Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0         284229510                        NaN                  IR
# 1         284229513                        NaN                  IR
# 2         284229514                        NaN                  IR
# 3         284229515                        NaN                  IR
# 4         284229516                        NaN                  IR
#
#                        Product ID Action Transaction Type  \
# 0         InterestRate:IRSwap:OIS    NEW            Trade
# 1  InterestRate:IRSwap:FixedFloat    NEW      Termination
# 2         InterestRate:IRSwap:OIS    NEW            Trade
# 3         InterestRate:IRSwap:OIS    NEW            Trade
# 4         InterestRate:IRSwap:OIS    NEW            Trade
#
#   Block Trade Election Indicator Cleared  \
# 0                              N       C
# 1                              N       U
# 2                              N       U
# 3                              N       U
# 4                              N       U
#
#   Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                         N              ACT/360  ...
# 1                                       NaN        ACT/365.FIXED  ...
# 2                                         N        ACT/365.FIXED  ...
# 3                                         N        ACT/365.FIXED  ...
# 4                                         N        ACT/365.FIXED  ...
#
#   Strike Price Currency            Underlying Asset ID  \
# 0                   NaN          USD-SOFR-OIS COMPOUND
# 1                   NaN  CNY_REPO_CNRR007_BLMBERG_7DAY
# 2                   NaN          JPY-TONA-OIS COMPOUND
# 3                   NaN          JPY-TONA-OIS COMPOUND
# 4                   NaN          JPY-TONA-OIS COMPOUND
#
#   Underlying Asset ID Type  Underlying Asset Name  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#    Leg 1 - Commodity Instrument ID Leg 2 - Commodity Instrument ID  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
#   Option Type Option Style  Execution Venue Type  Collateralization Type
# 0         NaN          NaN                    ON                     NaN
# 1         NaN          NaN                   OFF                     NaN
# 2         NaN          NaN                   OFF                     NaN
# 3         NaN          NaN                   OFF                     NaN
# 4         NaN          NaN                   OFF                     NaN
#
# [5 rows x 69 columns]

# %%
raw_df_master
# Out:
#      Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0           284229510                        NaN                  IR
# 1           284229513                        NaN                  IR
# 2           284229514                        NaN                  IR
# 3           284229515                        NaN                  IR
# 4           284229516                        NaN                  IR
# ..                ...                        ...                 ...
# 458         267956451                267784031.0                  IR
# 459         267956452                267784031.0                  IR
# 460         267956453                267784031.0                  IR
# 461         267956454                267784031.0                  IR
# 462         267956455                267784031.0                  IR
#
#                          Product ID   Action Transaction Type  \
# 0           InterestRate:IRSwap:OIS      NEW            Trade
# 1    InterestRate:IRSwap:FixedFloat      NEW      Termination
# 2           InterestRate:IRSwap:OIS      NEW            Trade
# 3           InterestRate:IRSwap:OIS      NEW            Trade
# 4           InterestRate:IRSwap:OIS      NEW            Trade
# ..                              ...      ...              ...
# 458         InterestRate:IRSwap:OIS  CORRECT            Trade
# 459         InterestRate:IRSwap:OIS   CANCEL            Trade
# 460         InterestRate:IRSwap:OIS  CORRECT            Trade
# 461         InterestRate:IRSwap:OIS   CANCEL            Trade
# 462         InterestRate:IRSwap:OIS  CORRECT            Trade
#
#     Block Trade Election Indicator Cleared  \
# 0                                N       C
# 1                                N       U
# 2                                N       U
# 3                                N       U
# 4                                N       U
# ..                             ...     ...
# 458                              N       U
# 459                              N       U
# 460                              N       U
# 461                              N       U
# 462                              N       U
#
#     Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                           N              ACT/360  ...
# 1                                         NaN        ACT/365.FIXED  ...
# 2                                           N        ACT/365.FIXED  ...
# 3                                           N        ACT/365.FIXED  ...
# 4                                           N        ACT/365.FIXED  ...
# ..                                        ...                  ...  ...
# 458                                         N        ACT/365.FIXED  ...
# 459                                         N        ACT/365.FIXED  ...
# 460                                         N        ACT/365.FIXED  ...
# 461                                         N        ACT/365.FIXED  ...
# 462                                         N        ACT/365.FIXED  ...
#
#     Strike Price Currency            Underlying Asset ID  \
# 0                     NaN          USD-SOFR-OIS COMPOUND
# 1                     NaN  CNY_REPO_CNRR007_BLMBERG_7DAY
# 2                     NaN          JPY-TONA-OIS COMPOUND
# 3                     NaN          JPY-TONA-OIS COMPOUND
# 4                     NaN          JPY-TONA-OIS COMPOUND
# ..                    ...                            ...
# 458                   NaN                          FIXED
# 459                   NaN                          FIXED
# 460                   NaN                          FIXED
# 461                   NaN                          FIXED
# 462                   NaN                          FIXED
#
#     Underlying Asset ID Type  Underlying Asset Name  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ..                       ...                    ...
# 458                      NaN                    NaN
# 459                      NaN                    NaN
# 460                      NaN                    NaN
# 461                      NaN                    NaN
# 462                      NaN                    NaN
#
#      Leg 1 - Commodity Instrument ID Leg 2 - Commodity Instrument ID  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 458                              NaN                             NaN
# 459                              NaN                             NaN
# 460                              NaN                             NaN
# 461                              NaN                             NaN
# 462                              NaN                             NaN
#
#     Option Type Option Style  Execution Venue Type  Collateralization Type
# 0           NaN          NaN                    ON                     NaN
# 1           NaN          NaN                   OFF                     NaN
# 2           NaN          NaN                   OFF                     NaN
# 3           NaN          NaN                   OFF                     NaN
# 4           NaN          NaN                   OFF                     NaN
# ..          ...          ...                   ...                     ...
# 458         NaN          NaN                   OFF                     NaN
# 459         NaN          NaN                   OFF                     NaN
# 460         NaN          NaN                   OFF                     NaN
# 461         NaN          NaN                   OFF                     NaN
# 462         NaN          NaN                   OFF                     NaN
#
# [432800 rows x 69 columns]

# %%
raw_df_master['Transaction Type'].unique()
# Out:
# array(['Trade', 'Termination', 'Amendment', 'Novation', 'Increase'],
#       dtype=object)

# %%
relevant_columns = ['Product ID', 'Action', 'Transaction Type',  'Effective Date',
                    'Expiration Date', 'Leg 1 - Floating Rate Index', 'Leg 2 - Floating Rate Index', 
                    'Notional Amount 1', 'Notional Currency 1']

raw_df_master[relevant_columns]
# Out:
#                          Product ID   Action Transaction Type Effective Date  \
# 0           InterestRate:IRSwap:OIS      NEW            Trade     2022-02-24
# 1    InterestRate:IRSwap:FixedFloat      NEW      Termination     2021-09-15
# 2           InterestRate:IRSwap:OIS      NEW            Trade     2022-03-16
# 3           InterestRate:IRSwap:OIS      NEW            Trade     2022-03-16
# 4           InterestRate:IRSwap:OIS      NEW            Trade     2022-03-16
# ..                              ...      ...              ...            ...
# 458         InterestRate:IRSwap:OIS  CORRECT            Trade     2022-01-21
# 459         InterestRate:IRSwap:OIS   CANCEL            Trade     2022-01-21
# 460         InterestRate:IRSwap:OIS  CORRECT            Trade     2022-01-21
# 461         InterestRate:IRSwap:OIS   CANCEL            Trade     2022-01-21
# 462         InterestRate:IRSwap:OIS  CORRECT            Trade     2022-01-21
#
#     Expiration Date    Leg 1 - Floating Rate Index  \
# 0        2032-02-24          USD-SOFR-OIS COMPOUND
# 1        2026-09-15  CNY_REPO_CNRR007_BLMBERG_7DAY
# 2        2052-03-20          JPY-TONA-OIS COMPOUND
# 3        2052-03-20          JPY-TONA-OIS COMPOUND
# 4        2032-03-17          JPY-TONA-OIS COMPOUND
# ..              ...                            ...
# 458      2044-01-22                            NaN
# 459      2044-01-22                            NaN
# 460      2044-01-22                            NaN
# 461      2044-01-22                            NaN
# 462      2044-01-22                            NaN
#
#     Leg 2 - Floating Rate Index Notional Amount 1 Notional Currency 1
# 0                           NaN       100,000,000                 USD
# 1                           NaN        22,000,000                 CNY
# 2                           NaN     2,000,000,000                 JPY
# 3                           NaN     2,000,000,000                 JPY
# 4                           NaN     7,000,000,000                 JPY
# ..                          ...               ...                 ...
# 458      GBP-SONIA-OIS COMPOUND        57,000,000                 GBP
# 459      GBP-SONIA-OIS COMPOUND        57,000,000                 GBP
# 460      GBP-SONIA-OIS COMPOUND        57,000,000                 GBP
# 461      GBP-SONIA-OIS COMPOUND        57,000,000                 GBP
# 462      GBP-SONIA-OIS COMPOUND        57,000,000                 GBP
#
# [432800 rows x 9 columns]

# %%
raw_df_master['Notional Currency 1'].unique()
# Out:
# array(['USD', 'CNY', 'JPY', 'KRW', 'CLP', 'EUR', 'GBP', 'TRY', 'CZK',
#        'NZD', 'CHF', 'PLN', 'BRL', 'CAD', 'MYR', 'NOK', 'MXN', 'SEK',
#        'ILS', 'ZAR', 'HUF', 'SGD', 'SAR', 'AUD', 'RUB', 'IDR', 'COP',
#        'MXV', 'PEN', 'THB', 'INR', 'CLF', 'GEL', 'HKD', 'TWD', 'DKK',
#        'PHP', 'GHS', 'RON', 'UAH', 'AED', nan, 'NGN', 'PKR', 'KES'],
#       dtype=object)

# %%
import investpy
# these currencies do not exist in the FX data so must ignore
[x for x in raw_df_master['Notional Currency 1'].unique() if x not in investpy.currency_crosses.get_available_currencies()]
# Out:
# ['MXV', 'CLF', nan]

# %%
raw_df_master[raw_df_master['Notional Currency 1'].isin(['CLF', 'MXV', pd.NA])]
# Out:
#       Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 1676         285282514                        NaN                  IR
# 1750         285286795                272234043.0                  IR
# 1751         285286796                272234043.0                  IR
# 3283         285155493                        NaN                  IR
# 3842         285143024                        NaN                  IR
# ...                ...                        ...                 ...
# 6525         268536798                        NaN                  IR
# 6526         268536799                        NaN                  IR
# 6535         268536928                        NaN                  IR
# 7882         268513729                        NaN                  IR
# 8346         268494085                        NaN                  IR
#
#                                  Product ID   Action Transaction Type  \
# 1676  InterestRate:CrossCurrency:FixedFloat      NEW            Trade
# 1750  InterestRate:CrossCurrency:FixedFloat   CANCEL            Trade
# 1751  InterestRate:CrossCurrency:FixedFloat  CORRECT            Trade
# 3283  InterestRate:CrossCurrency:FixedFloat      NEW            Trade
# 3842  InterestRate:CrossCurrency:FixedFloat      NEW            Trade
# ...                                     ...      ...              ...
# 6525  InterestRate:CrossCurrency:FixedFloat      NEW            Trade
# 6526                    InterestRate:Exotic      NEW        Amendment
# 6535  InterestRate:CrossCurrency:FixedFloat      NEW            Trade
# 7882                    InterestRate:Exotic      NEW        Amendment
# 8346                    InterestRate:Exotic      NEW        Amendment
#
#      Block Trade Election Indicator Cleared  \
# 1676                              N       U
# 1750                              N       U
# 1751                              N       U
# 3283                              N       U
# 3842                              N       U
# ...                             ...     ...
# 6525                              N       U
# 6526                              Y       U
# 6535                              N       U
# 7882                              N       U
# 8346                              Y       U
#
#      Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 1676                                       NaN              ACT/360  ...
# 1750                                       NaN              ACT/360  ...
# 1751                                       NaN              ACT/360  ...
# 3283                                       NaN              ACT/360  ...
# 3842                                       NaN              ACT/360  ...
# ...                                        ...                  ...  ...
# 6525                                       NaN              ACT/360  ...
# 6526                                       NaN               30/360  ...
# 6535                                       NaN              ACT/360  ...
# 7882                                       NaN               30/360  ...
# 8346                                       NaN               30/360  ...
#
#      Strike Price Currency Underlying Asset ID Underlying Asset ID Type  \
# 1676                   NaN                 NaN                      NaN
# 1750                   NaN               FIXED                      NaN
# 1751                   NaN               FIXED                      NaN
# 3283                   NaN                 NaN                      NaN
# 3842                   NaN                 NaN                      NaN
# ...                    ...                 ...                      ...
# 6525                   NaN                 NaN                      NaN
# 6526                   NaN                 NaN                      NaN
# 6535                   NaN                 NaN                      NaN
# 7882                   NaN                 NaN                      NaN
# 8346                   NaN                 NaN                      NaN
#
#       Underlying Asset Name  Leg 1 - Commodity Instrument ID  \
# 1676                    NaN                              NaN
# 1750                    NaN                              NaN
# 1751                    NaN                              NaN
# 3283                    NaN                              NaN
# 3842                    NaN                              NaN
# ...                     ...                              ...
# 6525                    NaN                              NaN
# 6526                    NaN                              NaN
# 6535                    NaN                              NaN
# 7882                    NaN                              NaN
# 8346                    NaN                              NaN
#
#      Leg 2 - Commodity Instrument ID Option Type Option Style  \
# 1676                             NaN         NaN          NaN
# 1750                             NaN         NaN          NaN
# 1751                             NaN         NaN          NaN
# 3283                             NaN         NaN          NaN
# 3842                             NaN         NaN          NaN
# ...                              ...         ...          ...
# 6525                             NaN         NaN          NaN
# 6526                             NaN         NaN          NaN
# 6535                             NaN         NaN          NaN
# 7882                             NaN         NaN          NaN
# 8346                             NaN         NaN          NaN
#
#       Execution Venue Type  Collateralization Type
# 1676                    ON                     NaN
# 1750                   OFF                     NaN
# 1751                   OFF                     NaN
# 3283                    ON                     NaN
# 3842                    ON                     NaN
# ...                    ...                     ...
# 6525                    ON                     NaN
# 6526                   OFF                     NaN
# 6535                    ON                     NaN
# 7882                   OFF                     NaN
# 8346                   OFF                     NaN
#
# [541 rows x 69 columns]

# %%
pd.to_datetime(raw_df_master['Effective Date']).sort_values()
# Out:
# 3062    1993-08-12
# 6737    1997-12-23
# 8199    1998-01-08
# 54      1998-07-03
# 55      1998-07-03
#            ...
# 6       2062-07-03
# 3717    2066-12-15
# 9279    2067-02-04
# 27944   2067-02-04
# 7019    2068-06-18
# Name: Effective Date, Length: 432800, dtype: datetime64[ns]

# %%
raw_df_master[raw_df_master['Dissemination ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Dissemination ID, Original Dissemination ID, Primary Asset Class, Product ID, Action, Transaction Type, Block Trade Election Indicator, Cleared, Clearing Exception or Exemption Indicator, Day Count Convention, Effective Date, Embedded Option Type, Event Timestamp, Exchange Rate, Exchange Rate Basis, Execution Timestamp, Expiration Date, First Exercise Date, Fixed Rate 1, Fixed Rate 2, Fixed Recovery CDS Final Price, Floating Rate Reset Frequency Period 1, Floating Rate Reset Frequency Period 2, Floating Rate Reset Frequency Period Multiplier 1, Floating Rate Reset Frequency Period Multiplier 2, Leg 1 - Commodity Underlyer ID, Leg 2 - Commodity Underlyer ID, Leg 1 - Floating Rate Index, Leg 2 - Floating Rate Index, Non-Standardized Pricing Indicator, Notional Amount 1, Notional Amount 2, Notional Currency 1, Notional Currency 2, Notional Quantity 1, Notional Quantity 2, Total Notional Quantity 1, Total Notional Quantity 2, Option Entitlement, Option Premium Amount, Option Premium Currency, Other Payment Amount, Payment Frequency Period 1, Payment Frequency Period 2, Payment Frequency Period Multiplier 1, Payment Frequency Period Multiplier 2, Price 1, Price 2, Price Unit Of Measure 1, Price Unit Of Measure 2, Quantity Frequency, Quantity Unit Of Measure, Settlement Currency 1, Settlement Currency 2, Spread 1, Spread 2, Spread Currency 1, Spread Currency 2, Strike Price, Strike Price Currency, Underlying Asset ID, Underlying Asset ID Type, Underlying Asset Name, Leg 1 - Commodity Instrument ID, Leg 2 - Commodity Instrument ID, Option Type, Option Style, Execution Venue Type, Collateralization Type]
# Index: []
#
# [0 rows x 69 columns]

# %%
# this series has no NaN data -> perfect for currency conversion!
raw_df_master['Event Timestamp'][raw_df_master['Event Timestamp'].isna()]
# Out:
# Series([], Name: Event Timestamp, dtype: object)

# %%
# incorrectly entered data -> further investigation required to really know where it belongs, lets ignore
raw_df_master['Event Timestamp'][pd.to_datetime(raw_df_master['Event Timestamp'], errors='coerce').isna()]
# Out:
# 4233     0022-02-20T00:30:00
# 10696    0022-02-20T14:22:00
# 10697    0022-02-20T14:22:00
# 12404    0022-02-13T15:59:00
# 12408    0022-02-13T16:57:00
# 13710    0022-02-13T16:57:00
# 15700    0022-02-13T13:40:00
# 1430     0022-02-05T15:47:00
# Name: Event Timestamp, dtype: object

# %%
raw_df_master['Event Timestamp'][~pd.to_datetime(raw_df_master['Event Timestamp'], errors='coerce').isna()]
# Out:
# 0      2022-02-22T02:12:21
# 1      2022-02-22T02:12:36
# 2      2022-02-22T02:09:49
# 3      2022-02-22T02:09:47
# 4      2022-02-22T02:09:44
#               ...
# 458    2022-01-21T13:08:57
# 459    2022-01-21T08:08:57
# 460    2022-01-21T13:08:57
# 461    2022-01-21T08:08:57
# 462    2022-01-21T13:08:57
# Name: Event Timestamp, Length: 432792, dtype: object

# %%
# removing strange timestamps
raw_df_master = raw_df_master[~pd.to_datetime(raw_df_master['Event Timestamp'], errors='coerce').isna()]
raw_df_master = raw_df_master[raw_df_master['Event Timestamp'] != '1970-01-01T00:00:00']
#removing irrelevan fx data
bad_currencies = [x for x in raw_df_master['Notional Currency 1'].unique() if x not in investpy.currency_crosses.get_available_currencies()]

# %%
raw_df_master = raw_df_master[~raw_df_master['Notional Currency 1'].isin(bad_currencies)]
raw_df_master['exch_date'] = pd.to_datetime(raw_df_master['Event Timestamp']).dt.date
raw_df_master
# Out:
#      Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0           284229510                        NaN                  IR
# 1           284229513                        NaN                  IR
# 2           284229514                        NaN                  IR
# 3           284229515                        NaN                  IR
# 4           284229516                        NaN                  IR
# ..                ...                        ...                 ...
# 458         267956451                267784031.0                  IR
# 459         267956452                267784031.0                  IR
# 460         267956453                267784031.0                  IR
# 461         267956454                267784031.0                  IR
# 462         267956455                267784031.0                  IR
#
#                          Product ID   Action Transaction Type  \
# 0           InterestRate:IRSwap:OIS      NEW            Trade
# 1    InterestRate:IRSwap:FixedFloat      NEW      Termination
# 2           InterestRate:IRSwap:OIS      NEW            Trade
# 3           InterestRate:IRSwap:OIS      NEW            Trade
# 4           InterestRate:IRSwap:OIS      NEW            Trade
# ..                              ...      ...              ...
# 458         InterestRate:IRSwap:OIS  CORRECT            Trade
# 459         InterestRate:IRSwap:OIS   CANCEL            Trade
# 460         InterestRate:IRSwap:OIS  CORRECT            Trade
# 461         InterestRate:IRSwap:OIS   CANCEL            Trade
# 462         InterestRate:IRSwap:OIS  CORRECT            Trade
#
#     Block Trade Election Indicator Cleared  \
# 0                                N       C
# 1                                N       U
# 2                                N       U
# 3                                N       U
# 4                                N       U
# ..                             ...     ...
# 458                              N       U
# 459                              N       U
# 460                              N       U
# 461                              N       U
# 462                              N       U
#
#     Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                           N              ACT/360  ...
# 1                                         NaN        ACT/365.FIXED  ...
# 2                                           N        ACT/365.FIXED  ...
# 3                                           N        ACT/365.FIXED  ...
# 4                                           N        ACT/365.FIXED  ...
# ..                                        ...                  ...  ...
# 458                                         N        ACT/365.FIXED  ...
# 459                                         N        ACT/365.FIXED  ...
# 460                                         N        ACT/365.FIXED  ...
# 461                                         N        ACT/365.FIXED  ...
# 462                                         N        ACT/365.FIXED  ...
#
#                Underlying Asset ID Underlying Asset ID Type  \
# 0            USD-SOFR-OIS COMPOUND                      NaN
# 1    CNY_REPO_CNRR007_BLMBERG_7DAY                      NaN
# 2            JPY-TONA-OIS COMPOUND                      NaN
# 3            JPY-TONA-OIS COMPOUND                      NaN
# 4            JPY-TONA-OIS COMPOUND                      NaN
# ..                             ...                      ...
# 458                          FIXED                      NaN
# 459                          FIXED                      NaN
# 460                          FIXED                      NaN
# 461                          FIXED                      NaN
# 462                          FIXED                      NaN
#
#     Underlying Asset Name  Leg 1 - Commodity Instrument ID  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
# ..                    ...                              ...
# 458                   NaN                              NaN
# 459                   NaN                              NaN
# 460                   NaN                              NaN
# 461                   NaN                              NaN
# 462                   NaN                              NaN
#
#      Leg 2 - Commodity Instrument ID Option Type Option Style  \
# 0                                NaN         NaN          NaN
# 1                                NaN         NaN          NaN
# 2                                NaN         NaN          NaN
# 3                                NaN         NaN          NaN
# 4                                NaN         NaN          NaN
# ..                               ...         ...          ...
# 458                              NaN         NaN          NaN
# 459                              NaN         NaN          NaN
# 460                              NaN         NaN          NaN
# 461                              NaN         NaN          NaN
# 462                              NaN         NaN          NaN
#
#     Execution Venue Type  Collateralization Type   exch_date
# 0                     ON                     NaN  2022-02-22
# 1                    OFF                     NaN  2022-02-22
# 2                    OFF                     NaN  2022-02-22
# 3                    OFF                     NaN  2022-02-22
# 4                    OFF                     NaN  2022-02-22
# ..                   ...                     ...         ...
# 458                  OFF                     NaN  2022-01-21
# 459                  OFF                     NaN  2022-01-21
# 460                  OFF                     NaN  2022-01-21
# 461                  OFF                     NaN  2022-01-21
# 462                  OFF                     NaN  2022-01-21
#
# [432246 rows x 70 columns]

# %%
raw_df_master.groupby('Notional Currency 1')['exch_date'].agg(['min', 'max']).head(5)
# Out:
#                             min         max
# Notional Currency 1
# AED                  2018-02-12  2022-02-15
# AUD                  2015-04-28  2022-02-22
# BRL                  2019-07-17  2022-02-22
# CAD                  2010-10-07  2022-02-22
# CHF                  2014-02-05  2022-02-22

# %%
base_currency = 'USD'
raw_df_master.groupby('Notional Currency 1')['exch_date'].agg(['min', 'max']).head(5).reset_index()
# Out:
#   Notional Currency 1         min         max
# 0                 AED  2018-02-12  2022-02-15
# 1                 AUD  2015-04-28  2022-02-22
# 2                 BRL  2019-07-17  2022-02-22
# 3                 CAD  2010-10-07  2022-02-22
# 4                 CHF  2014-02-05  2022-02-22

# %%
investpy.get_currency_cross_historical_data(currency_cross='AED/USD', from_date='12/02/2018', to_date='15/02/2022')
# Out:
#               Open    High     Low   Close Currency
# Date
# 2018-02-12  0.2722  0.2723  0.2722  0.2722      USD
# 2018-02-13  0.2722  0.2722  0.2722  0.2722      USD
# 2018-02-14  0.2722  0.2722  0.2722  0.2722      USD
# 2018-02-15  0.2722  0.2722  0.2722  0.2722      USD
# 2018-02-16  0.2722  0.2722  0.2722  0.2722      USD
# ...            ...     ...     ...     ...      ...
# 2022-02-09  0.2723  0.2723  0.2722  0.2722      USD
# 2022-02-10  0.2723  0.2723  0.2722  0.2722      USD
# 2022-02-11  0.2723  0.2723  0.2722  0.2722      USD
# 2022-02-14  0.2722  0.2723  0.2722  0.2722      USD
# 2022-02-15  0.2723  0.2723  0.2722  0.2722      USD
#
# [1047 rows x 5 columns]

# %%
import time

# probably best to order by date and then currency, rather than currency first and date second
currency_conv_dict = {}
unavailable_currencies = []

for index, row in exchange_rates_df.groupby('Notional Currency 1')['exch_date'].agg(['min', 'max']).reset_index().iterrows():
    start_date = row['min'].strftime('%d/%m/%Y')
    end_date = row['max'].strftime('%d/%m/%Y')
    currency_cross = f'{row["Notional Currency 1"]}/{base_currency}'
    print('Requesting fx data:' , currency_cross, start_date, end_date)
    try:
        df_fx = investpy.get_currency_cross_historical_data(currency_cross=f'{row["Notional Currency 1"]}/{base_currency}', 
                                    from_date=start_date, to_date=end_date)['Close']
        df_fx.index = df_fx.index.strftime('%d/%m/%Y')        
        currency_conv_dict[currency_cross] = df_fx.to_dict()
        time.sleep(1)
    except:
        print('Unable to find data for ', currency_cross)
        if base_currency == 'USD':
            temp_base_currency = 'EUR'
        elif base_currency == 'EUR':
            temp_base_currency = 'USD'
        currency_cross = f'{row["Notional Currency 1"]}/{temp_base_currency}'
        print('Requesting fx data:' , currency_cross, start_date, end_date)
        try:
            df_fx = investpy.get_currency_cross_historical_data(currency_cross=f'{row["Notional Currency 1"]}/{temp_base_currency}', 
                                        from_date=start_date, to_date=end_date)['Close']
            df_fx.index = df_fx.index.strftime('%d/%m/%Y')        
            currency_conv_dict[currency_cross] = df_fx.to_dict()
            time.sleep(1)
        except:
            print('Unable to find data for ', currency_cross)
            unavailable_currencies.append(row["Notional Currency 1"])
            print('Stopping search for this currency: ', row["Notional Currency 1"])
# Out:
# Requesting fx data: AED/USD 12/02/2018 15/02/2022
# Requesting fx data: AUD/USD 28/04/2015 20/02/2022
# Requesting fx data: BRL/USD 17/07/2019 20/02/2022
# Requesting fx data: CAD/USD 07/10/2010 18/02/2022
# Requesting fx data: CHF/USD 09/02/2015 18/02/2022
# Requesting fx data: CLP/USD 02/04/2014 18/02/2022
# Requesting fx data: CNY/USD 04/11/2019 18/02/2022
# Requesting fx data: COP/USD 31/03/2020 18/02/2022
# Requesting fx data: CZK/USD 09/04/2021 18/02/2022
# Unable to find data for  CZK/USD
# Requesting fx data: CZK/EUR 09/04/2021 18/02/2022
# Unable to find data for  CZK/EUR
# Stopping search for this currency:  CZK
# Requesting fx data: DKK/USD 07/02/2013 18/02/2022
# Requesting fx data: EUR/USD 08/10/2003 19/02/2022
# Requesting fx data: GBP/USD 15/02/2001 19/02/2022
# Requesting fx data: GEL/USD 18/01/2022 16/02/2022
# Unable to find data for  GEL/USD
# Requesting fx data: GEL/EUR 18/01/2022 16/02/2022
# Requesting fx data: GHS/USD 10/02/2022 14/02/2022
# Requesting fx data: HKD/USD 26/05/2017 18/02/2022
# Requesting fx data: HUF/USD 10/02/2015 18/02/2022
# Requesting fx data: IDR/USD 22/01/2018 17/02/2022
# Requesting fx data: ILS/USD 14/03/2017 18/02/2022
# Requesting fx data: INR/USD 08/02/2017 18/02/2022
# Requesting fx data: JPY/USD 19/12/2003 20/02/2022
# Requesting fx data: KES/USD 06/01/2022 25/01/2022
# Unable to find data for  KES/USD
# Requesting fx data: KES/EUR 06/01/2022 25/01/2022
# Unable to find data for  KES/EUR
# Stopping search for this currency:  KES
# Requesting fx data: KRW/USD 10/02/2012 19/02/2022
# Requesting fx data: MXN/USD 13/09/2011 18/02/2022
# Requesting fx data: MYR/USD 21/11/2018 18/02/2022
# Requesting fx data: NGN/USD 28/01/2022 28/01/2022
# Unable to find data for  NGN/USD
# Requesting fx data: NGN/EUR 28/01/2022 28/01/2022
# Unable to find data for  NGN/EUR
# Stopping search for this currency:  NGN
# Requesting fx data: NOK/USD 10/11/2017 18/02/2022
# Requesting fx data: NZD/USD 17/02/2016 20/02/2022
# Requesting fx data: PEN/USD 14/08/2013 18/02/2022
# Requesting fx data: PHP/USD 03/02/2021 04/02/2022
# Requesting fx data: PKR/USD 26/04/2021 02/08/2021
# Unable to find data for  PKR/USD
# Requesting fx data: PKR/EUR 26/04/2021 02/08/2021
# Unable to find data for  PKR/EUR
# Stopping search for this currency:  PKR
# Requesting fx data: PLN/USD 12/02/2016 18/02/2022
# Requesting fx data: RON/USD 25/01/2022 14/02/2022
# Unable to find data for  RON/USD
# Requesting fx data: RON/EUR 25/01/2022 14/02/2022
# Unable to find data for  RON/EUR
# Stopping search for this currency:  RON
# Requesting fx data: RUB/USD 06/07/2020 18/02/2022
# Requesting fx data: SAR/USD 13/02/2020 17/02/2022
# Requesting fx data: SEK/USD 05/11/2018 18/02/2022
# Requesting fx data: SGD/USD 19/04/2012 18/02/2022
# Requesting fx data: THB/USD 17/02/2016 18/02/2022
# Requesting fx data: TRY/USD 20/12/2019 18/02/2022
# Requesting fx data: TWD/USD 11/03/2013 18/02/2022
# Requesting fx data: UAH/USD 18/01/2021 17/02/2022
# Requesting fx data: USD/USD 31/12/1999 20/02/2022
# Unable to find data for  USD/USD
# Requesting fx data: USD/EUR 31/12/1999 20/02/2022
# Requesting fx data: ZAR/USD 01/06/2017 18/02/2022

# %%
unavailable_currencies
# Out:
# ['CZK', 'KES', 'NGN', 'PKR', 'RON']

# %%
raw_df_master.shape
# Out:
# (432246, 70)

# %%
raw_df_master = raw_df_master[~raw_df_master['Notional Currency 1'].isin(unavailable_currencies)]

# %%
raw_df_master['notional_amount_1_clean'] = pd.to_numeric(raw_df_master['Notional Amount 1'].apply(lambda x: re.compile(r'[^\d.]+').sub('', x)))
# Out:
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/2120104416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_df_master['notional_amount_1_clean'] = pd.to_numeric(raw_df_master['Notional Amount 1'].apply(lambda x: re.compile(r'[^\d.]+').sub('', x)))

# %%
raw_df_master.shape
# Out:
# (426583, 70)

# %%
raw_df_master.head(10)
# Out:
#    Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0         284229510                        NaN                  IR
# 1         284229513                        NaN                  IR
# 2         284229514                        NaN                  IR
# 3         284229515                        NaN                  IR
# 4         284229516                        NaN                  IR
# 5         284229517                        NaN                  IR
# 6         284229518                        NaN                  IR
# 7         284229519                        NaN                  IR
# 8         284229520                        NaN                  IR
# 9         284229521                        NaN                  IR
#
#                        Product ID Action Transaction Type  \
# 0         InterestRate:IRSwap:OIS    NEW            Trade
# 1  InterestRate:IRSwap:FixedFloat    NEW      Termination
# 2         InterestRate:IRSwap:OIS    NEW            Trade
# 3         InterestRate:IRSwap:OIS    NEW            Trade
# 4         InterestRate:IRSwap:OIS    NEW            Trade
# 5         InterestRate:IRSwap:OIS    NEW            Trade
# 6         InterestRate:IRSwap:OIS    NEW            Trade
# 7         InterestRate:IRSwap:OIS    NEW            Trade
# 8         InterestRate:IRSwap:OIS    NEW            Trade
# 9         InterestRate:IRSwap:OIS    NEW            Trade
#
#   Block Trade Election Indicator Cleared  \
# 0                              N       C
# 1                              N       U
# 2                              N       U
# 3                              N       U
# 4                              N       U
# 5                              N       U
# 6                              N       U
# 7                              N       U
# 8                              N       U
# 9                              N       U
#
#   Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                         N              ACT/360  ...
# 1                                       NaN        ACT/365.FIXED  ...
# 2                                         N        ACT/365.FIXED  ...
# 3                                         N        ACT/365.FIXED  ...
# 4                                         N        ACT/365.FIXED  ...
# 5                                         N        ACT/365.FIXED  ...
# 6                                         N        ACT/365.FIXED  ...
# 7                                         N        ACT/365.FIXED  ...
# 8                                         N        ACT/365.FIXED  ...
# 9                                         N        ACT/365.FIXED  ...
#
#   Underlying Asset ID Type Underlying Asset Name  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# 5                      NaN                   NaN
# 6                      NaN                   NaN
# 7                      NaN                   NaN
# 8                      NaN                   NaN
# 9                      NaN                   NaN
#
#   Leg 1 - Commodity Instrument ID  Leg 2 - Commodity Instrument ID  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
#
#    Option Type Option Style Execution Venue Type Collateralization Type  \
# 0          NaN          NaN                   ON                    NaN
# 1          NaN          NaN                  OFF                    NaN
# 2          NaN          NaN                  OFF                    NaN
# 3          NaN          NaN                  OFF                    NaN
# 4          NaN          NaN                  OFF                    NaN
# 5          NaN          NaN                  OFF                    NaN
# 6          NaN          NaN                  OFF                    NaN
# 7          NaN          NaN                  OFF                    NaN
# 8          NaN          NaN                  OFF                    NaN
# 9          NaN          NaN                  OFF                    NaN
#
#     exch_date  notional_amount_1_clean
# 0  2022-02-22                100000000
# 1  2022-02-22                 22000000
# 2  2022-02-22               2000000000
# 3  2022-02-22               2000000000
# 4  2022-02-22               7000000000
# 5  2022-02-22              11000000000
# 6  2022-02-22               7000000000
# 7  2022-02-22               2000000000
# 8  2022-02-22               6000000000
# 9  2022-02-22               4000000000
#
# [10 rows x 71 columns]

# %%
def convert_to_base_notional(r):
    #TODO - finalise and retest logic - easy to break the flow, needs further testing
    relevant_exchange_pair = f'{r["Notional Currency 1"]}/{base_currency}'
    if relevant_exchange_pair in ['EUR/EUR', 'USD/USD']:
        relevant_exchange_rate = 1
    else:
        # TODO - this only assumes  two currencies are possible 
        if base_currency == 'USD':
            second_base = 'EUR'
        else:
            second_base = 'USD'

        second_pair = f'{r["Notional Currency 1"]}/{second_base}'
        exchange_date = r['exch_date'].strftime('%d/%m/%Y')
        fx_pair = currency_conv_dict.get(relevant_exchange_pair)
        if not fx_pair:
            fx_pair = currency_conv_dict.get(second_pair)
        relevant_exchange_rate = fx_pair.get(exchange_date)
        
        if not relevant_exchange_rate:
            last_30_days = [x.strftime('%d/%m/%Y') for x in pd.date_range(end=r['exch_date'], periods=30).tolist()][::-1]
            for date in last_30_days:
                if fx_pair.get(date):
                    relevant_exchange_rate = fx_pair.get(date)
                    # rounded up to nearest integer for simplicity
                    #. correcting for JPY incorrect data
                    if relevant_exchange_pair == 'JPY/USD' or relevant_exchange_pair == 'JPY/EUR':
                        relevant_exchange_rate = relevant_exchange_rate / 100
                    base_amount = int(relevant_exchange_rate * r['notional_amount_1_clean'])
                    return base_amount
    if relevant_exchange_rate:
        # rounded up to nearest integer for simplicity
        #. correcting for JPY incorrect data
        if relevant_exchange_pair == 'JPY/USD' or relevant_exchange_pair == 'JPY/EUR':
            relevant_exchange_rate = relevant_exchange_rate / 100
        base_amount = int(relevant_exchange_rate * r['notional_amount_1_clean'])
        return base_amount
    else:
        return None

# some strange behaviour with automatic conversion to float...
raw_df_master['notional_1_base'] = raw_df_master[['notional_amount_1_clean', 'Notional Currency 1', 'exch_date']]. \
        apply(convert_to_base_notional, axis = 1).astype(int, errors='ignore')

raw_df_master.head(10)
# Out:
# /var/folders/0t/1b6bbpcj52xdthkg2d6g2sr40000gn/T/ipykernel_8711/766391944.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_df_master['notional_1_base'] = raw_df_master[['notional_amount_1_clean', 'Notional Currency 1', 'exch_date']]. \
#    Dissemination ID  Original Dissemination ID Primary Asset Class  \
# 0         284229510                        NaN                  IR
# 1         284229513                        NaN                  IR
# 2         284229514                        NaN                  IR
# 3         284229515                        NaN                  IR
# 4         284229516                        NaN                  IR
# 5         284229517                        NaN                  IR
# 6         284229518                        NaN                  IR
# 7         284229519                        NaN                  IR
# 8         284229520                        NaN                  IR
# 9         284229521                        NaN                  IR
#
#                        Product ID Action Transaction Type  \
# 0         InterestRate:IRSwap:OIS    NEW            Trade
# 1  InterestRate:IRSwap:FixedFloat    NEW      Termination
# 2         InterestRate:IRSwap:OIS    NEW            Trade
# 3         InterestRate:IRSwap:OIS    NEW            Trade
# 4         InterestRate:IRSwap:OIS    NEW            Trade
# 5         InterestRate:IRSwap:OIS    NEW            Trade
# 6         InterestRate:IRSwap:OIS    NEW            Trade
# 7         InterestRate:IRSwap:OIS    NEW            Trade
# 8         InterestRate:IRSwap:OIS    NEW            Trade
# 9         InterestRate:IRSwap:OIS    NEW            Trade
#
#   Block Trade Election Indicator Cleared  \
# 0                              N       C
# 1                              N       U
# 2                              N       U
# 3                              N       U
# 4                              N       U
# 5                              N       U
# 6                              N       U
# 7                              N       U
# 8                              N       U
# 9                              N       U
#
#   Clearing Exception or Exemption Indicator Day Count Convention  ...  \
# 0                                         N              ACT/360  ...
# 1                                       NaN        ACT/365.FIXED  ...
# 2                                         N        ACT/365.FIXED  ...
# 3                                         N        ACT/365.FIXED  ...
# 4                                         N        ACT/365.FIXED  ...
# 5                                         N        ACT/365.FIXED  ...
# 6                                         N        ACT/365.FIXED  ...
# 7                                         N        ACT/365.FIXED  ...
# 8                                         N        ACT/365.FIXED  ...
# 9                                         N        ACT/365.FIXED  ...
#
#   Underlying Asset Name Leg 1 - Commodity Instrument ID  \
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
# 3                   NaN                             NaN
# 4                   NaN                             NaN
# 5                   NaN                             NaN
# 6                   NaN                             NaN
# 7                   NaN                             NaN
# 8                   NaN                             NaN
# 9                   NaN                             NaN
#
#   Leg 2 - Commodity Instrument ID  Option Type  Option Style  \
# 0                             NaN          NaN           NaN
# 1                             NaN          NaN           NaN
# 2                             NaN          NaN           NaN
# 3                             NaN          NaN           NaN
# 4                             NaN          NaN           NaN
# 5                             NaN          NaN           NaN
# 6                             NaN          NaN           NaN
# 7                             NaN          NaN           NaN
# 8                             NaN          NaN           NaN
# 9                             NaN          NaN           NaN
#
#   Execution Venue Type Collateralization Type   exch_date  \
# 0                   ON                    NaN  2022-02-22
# 1                  OFF                    NaN  2022-02-22
# 2                  OFF                    NaN  2022-02-22
# 3                  OFF                    NaN  2022-02-22
# 4                  OFF                    NaN  2022-02-22
# 5                  OFF                    NaN  2022-02-22
# 6                  OFF                    NaN  2022-02-22
# 7                  OFF                    NaN  2022-02-22
# 8                  OFF                    NaN  2022-02-22
# 9                  OFF                    NaN  2022-02-22
#
#    notional_amount_1_clean  notional_1_base
# 0                100000000      100000000.0
# 1                 22000000        3478200.0
# 2               2000000000       17384000.0
# 3               2000000000       17384000.0
# 4               7000000000       60844000.0
# 5              11000000000       95612000.0
# 6               7000000000       60844000.0
# 7               2000000000       17384000.0
# 8               6000000000       52152000.0
# 9               4000000000       34768000.0
#
# [10 rows x 72 columns]

# %%
raw_df_master[raw_df_master['notional_1_base'].isna()][['notional_amount_1_clean', 'Notional Currency 1', 'exch_date', 'notional_1_base',]]
# Out:
#        notional_amount_1_clean Notional Currency 1   exch_date  \
# 1757               10245600000                 JPY  2017-02-22
# 3217                 120000000                 TRY  2018-12-12
# 3218                 120000000                 TRY  2018-12-12
# 3763                  25000000                 PLN  2014-09-04
# 3764                  25000000                 PLN  2014-09-04
# ...                        ...                 ...         ...
# 12965               5027220000                 JPY  2015-04-22
# 12968               1030140000                 JPY  2016-07-20
# 12969               1028295000                 JPY  2016-07-20
# 12998               3535705005                 JPY  2016-06-07
# 12999               3541905010                 JPY  2016-06-07
#
#        notional_1_base
# 1757               NaN
# 3217               NaN
# 3218               NaN
# 3763               NaN
# 3764               NaN
# ...                ...
# 12965              NaN
# 12968              NaN
# 12969              NaN
# 12998              NaN
# 12999              NaN
#
# [114 rows x 4 columns]

# %%
currency_conv_dict.get('JPY/USD').keys()
# Out:
# dict_keys(['15/02/2018', '16/02/2018', '19/02/2018', '20/02/2018', '21/02/2018', '22/02/2018', '23/02/2018', '26/02/2018', '27/02/2018', '28/02/2018', '01/03/2018', '02/03/2018', '05/03/2018', '06/03/2018', '07/03/2018', '08/03/2018', '09/03/2018', '12/03/2018', '13/03/2018', '14/03/2018', '15/03/2018', '16/03/2018', '19/03/2018', '20/03/2018', '21/03/2018', '22/03/2018', '23/03/2018', '26/03/2018', '27/03/2018', '28/03/2018', '29/03/2018', '30/03/2018', '02/04/2018', '03/04/2018', '04/04/2018', '05/04/2018', '06/04/2018', '09/04/2018', '10/04/2018', '11/04/2018', '12/04/2018', '13/04/2018', '16/04/2018', '17/04/2018', '18/04/2018', '19/04/2018', '20/04/2018', '23/04/2018', '24/04/2018', '25/04/2018', '26/04/2018', '27/04/2018', '30/04/2018', '01/05/2018', '02/05/2018', '03/05/2018', '04/05/2018', '07/05/2018', '08/05/2018', '09/05/2018', '10/05/2018', '11/05/2018', '14/05/2018', '15/05/2018', '16/05/2018', '17/05/2018', '18/05/2018', '21/05/2018', '22/05/2018', '23/05/2018', '24/05/2018', '25/05/2018', '28/05/2018', '29/05/2018', '30/05/2018', '31/05/2018', '01/06/2018', '04/06/2018', '05/06/2018', '06/06/2018', '07/06/2018', '08/06/2018', '11/06/2018', '12/06/2018', '13/06/2018', '14/06/2018', '15/06/2018', '18/06/2018', '19/06/2018', '20/06/2018', '21/06/2018', '22/06/2018', '25/06/2018', '26/06/2018', '27/06/2018', '28/06/2018', '29/06/2018', '02/07/2018', '03/07/2018', '04/07/2018', '05/07/2018', '06/07/2018', '09/07/2018', '10/07/2018', '11/07/2018', '12/07/2018', '13/07/2018', '16/07/2018', '17/07/2018', '18/07/2018', '19/07/2018', '20/07/2018', '23/07/2018', '24/07/2018', '25/07/2018', '26/07/2018', '27/07/2018', '30/07/2018', '31/07/2018', '01/08/2018', '02/08/2018', '03/08/2018', '06/08/2018', '07/08/2018', '08/08/2018', '09/08/2018', '10/08/2018', '13/08/2018', '14/08/2018', '15/08/2018', '16/08/2018', '17/08/2018', '20/08/2018', '21/08/2018', '22/08/2018', '23/08/2018', '24/08/2018', '27/08/2018', '28/08/2018', '29/08/2018', '30/08/2018', '31/08/2018', '03/09/2018', '04/09/2018', '05/09/2018', '06/09/2018', '07/09/2018', '10/09/2018', '11/09/2018', '12/09/2018', '13/09/2018', '14/09/2018', '17/09/2018', '18/09/2018', '19/09/2018', '20/09/2018', '21/09/2018', '24/09/2018', '25/09/2018', '26/09/2018', '27/09/2018', '28/09/2018', '01/10/2018', '02/10/2018', '03/10/2018', '04/10/2018', '05/10/2018', '08/10/2018', '09/10/2018', '10/10/2018', '11/10/2018', '12/10/2018', '15/10/2018', '16/10/2018', '17/10/2018', '18/10/2018', '19/10/2018', '22/10/2018', '23/10/2018', '24/10/2018', '25/10/2018', '26/10/2018', '29/10/2018', '30/10/2018', '31/10/2018', '01/11/2018', '02/11/2018', '05/11/2018', '06/11/2018', '07/11/2018', '08/11/2018', '09/11/2018', '12/11/2018', '13/11/2018', '14/11/2018', '15/11/2018', '16/11/2018', '19/11/2018', '20/11/2018', '21/11/2018', '22/11/2018', '23/11/2018', '26/11/2018', '27/11/2018', '28/11/2018', '29/11/2018', '30/11/2018', '03/12/2018', '04/12/2018', '05/12/2018', '06/12/2018', '07/12/2018', '10/12/2018', '11/12/2018', '12/12/2018', '13/12/2018', '14/12/2018', '17/12/2018', '18/12/2018', '19/12/2018', '20/12/2018', '21/12/2018', '24/12/2018', '25/12/2018', '26/12/2018', '27/12/2018', '28/12/2018', '31/12/2018', '01/01/2019', '02/01/2019', '03/01/2019', '04/01/2019', '07/01/2019', '08/01/2019', '09/01/2019', '10/01/2019', '11/01/2019', '14/01/2019', '15/01/2019', '16/01/2019', '17/01/2019', '18/01/2019', '21/01/2019', '22/01/2019', '23/01/2019', '24/01/2019', '25/01/2019', '28/01/2019', '29/01/2019', '30/01/2019', '31/01/2019', '01/02/2019', '04/02/2019', '05/02/2019', '06/02/2019', '07/02/2019', '08/02/2019', '11/02/2019', '12/02/2019', '13/02/2019', '14/02/2019', '15/02/2019', '18/02/2019', '19/02/2019', '20/02/2019', '21/02/2019', '22/02/2019', '25/02/2019', '26/02/2019', '27/02/2019', '28/02/2019', '01/03/2019', '04/03/2019', '05/03/2019', '06/03/2019', '07/03/2019', '08/03/2019', '11/03/2019', '12/03/2019', '13/03/2019', '14/03/2019', '15/03/2019', '18/03/2019', '19/03/2019', '20/03/2019', ...

# %%
final_df = raw_df_master[~raw_df_master['notional_1_base'].isna()].reset_index(drop=True)

# %%
final_df[['notional_amount_1_clean', 'Notional Currency 1', 'exch_date', 'notional_1_base']]
# Out:
#         notional_amount_1_clean Notional Currency 1   exch_date  \
# 0                     100000000                 USD  2022-02-22
# 1                      22000000                 CNY  2022-02-22
# 2                    2000000000                 JPY  2022-02-22
# 3                    2000000000                 JPY  2022-02-22
# 4                    7000000000                 JPY  2022-02-22
# ...                         ...                 ...         ...
# 426464                 57000000                 GBP  2022-01-21
# 426465                 57000000                 GBP  2022-01-21
# 426466                 57000000                 GBP  2022-01-21
# 426467                 57000000                 GBP  2022-01-21
# 426468                 57000000                 GBP  2022-01-21
#
#         notional_1_base
# 0           100000000.0
# 1             3478200.0
# 2            17384000.0
# 3            17384000.0
# 4            60844000.0
# ...                 ...
# 426464       77257800.0
# 426465       77257800.0
# 426466       77257800.0
# 426467       77257800.0
# 426468       77257800.0
#
# [426469 rows x 4 columns]

# %%
# checking some currencies for correct ordering...
final_df[['notional_amount_1_clean', 'Notional Currency 1', 'exch_date', 'notional_1_base']].loc[3]
# Out:
# notional_amount_1_clean    2000000000
# Notional Currency 1               JPY
# exch_date                  2022-02-22
# notional_1_base            17384000.0
# Name: 3, dtype: object

# %%
final_columns = ['Dissemination ID', 'Product ID', 'Action', 'Transaction Type',  'Effective Date',
                    'Expiration Date', 'Leg 1 - Floating Rate Index', 'Leg 2 - Floating Rate Index', 
                    'Notional Amount 1', 'Notional Currency 1', 'notional_amount_1_clean', 
                    'exch_date', 'notional_1_base']

# %%
final_df[final_columns].to_csv('../data/final_data.csv')

# %%
(final_df.groupby(['Product ID', 'Notional Currency 1']).sum()['notional_1_base']/1000000).astype(int). \
        sort_values(ascending=False).head(20)
# Out:
# Product ID                        Notional Currency 1
# InterestRate:IRSwap:FixedFloat    USD                    18024085
# InterestRate:IRSwap:OIS           USD                    13341178
# InterestRate:FRA                  EUR                     8255597
# InterestRate:IRSwap:OIS           EUR                     5257280
# InterestRate:IRSwap:FixedFloat    EUR                     4167236
# InterestRate:IRSwap:OIS           GBP                     3619271
# InterestRate:Option:Swaption      USD                     2643083
#                                   EUR                     1957076
# InterestRate:IRSwap:Basis         USD                     1824278
# InterestRate:IRSwap:OIS           AUD                     1344766
# InterestRate:CrossCurrency:Basis  EUR                     1325123
# InterestRate:IRSwap:FixedFloat    MXN                      986465
#                                   CAD                      697393
# InterestRate:Exotic               USD                      669715
# InterestRate:IRSwap:FixedFloat    AUD                      655481
# InterestRate:CrossCurrency:Basis  JPY                      531894
# InterestRate:IRSwap:OIS           JPY                      452361
#                                   CAD                      441014
# InterestRate:Option:Swaption      GBP                      426010
# InterestRate:IRSwap:FixedFloat    CLP                      410103
# Name: notional_1_base, dtype: int64

# %%
(final_df.groupby(['Notional Currency 1']).sum()['notional_1_base']/1000000).astype(int).\
        sort_values(ascending=False).head(20)
# Out:
# Notional Currency 1
# USD    37627916
# EUR    21946264
# GBP     4637125
# AUD     2223145
# CAD     1314966
# JPY     1151162
# MXN     1026097
# CLP      449760
# SEK      336953
# NZD      334651
# COP      230842
# ZAR      211712
# PLN      199911
# BRL      161986
# INR      137105
# KRW      134782
# CHF      131478
# CNY      125441
# NOK       80134
# SGD       65513
# Name: notional_1_base, dtype: int64

# %%
(final_df.groupby(['Product ID']).sum()['notional_1_base']/1000000).astype(int).sort_values(ascending=False).head(20)
# Out:
# Product ID
# InterestRate:IRSwap:FixedFloat           26151241
# InterestRate:IRSwap:OIS                  25137379
# InterestRate:FRA                          8930691
# InterestRate:Option:Swaption              5209519
# InterestRate:CrossCurrency:Basis          2928650
# InterestRate:IRSwap:Basis                 1988812
# InterestRate:Exotic                       1078865
# InterestRate:CapFloor                      796813
# InterestRate:IRSwap:Inflation              492843
# InterestRate:CrossCurrency:FixedFloat       79381
# InterestRate:CrossCurrency:FixedFixed       53363
# InterestRate:Option:DebtOption               2863
# InterestRate:IRSwap:FixedFixed               1684
# InterestRate:Forward:Debt                     417
# Name: notional_1_base, dtype: int64

# %%
(final_df.groupby(['Leg 1 - Floating Rate Index', 'Leg 2 - Floating Rate Index']). \
     sum()['notional_1_base']/1000000).astype(int).sort_values(ascending=False).head(30)
# Out:
# Leg 1 - Floating Rate Index  Leg 2 - Floating Rate Index
# EUR-EUROSTR-OIS COMPOUND     USD-SOFR-OIS COMPOUND                  967690
# USD-LIBOR                    USD-LIBOR                              821247
# USD-SOFR-OIS COMPOUND        USD-LIBOR                              408793
# JPY-TONA-OIS COMPOUND        USD-SOFR-OIS COMPOUND                  372323
# EUR-EUROSTR-COMPOUND         USD-SOFR-COMPOUND                      313091
# GBP-SONIA-OIS COMPOUND       USD-SOFR-OIS COMPOUND                  257981
# USD-SOFR-OIS COMPOUND        USD-FEDERAL FUNDS-OIS COMPOUND         229706
# JPY-TONA-OIS-COMPOUND        USD-SOFR-COMPOUND                      118192
# USD-LIBOR-BBA                USD-LIBOR-BBA                          101761
# GBP-SONIA-COMPOUND           USD-SOFR-COMPOUND                       98395
# AUD-BBSW                     USD-SOFR-OIS COMPOUND                   91100
# CAD-CDOR                     USD-SOFR-OIS COMPOUND                   70608
# USD-SOFR-COMPOUND            USD-LIBOR-BBA                           68313
# USD-LIBOR-BBA                USD-SOFR-COMPOUND                       55368
# EUR-EURIBOR-REUTERS          USD-LIBOR-BBA                           54736
# USD-SOFR-OIS COMPOUND        EUR-EUROSTR-OIS COMPOUND                51801
# USD-FEDERAL FUNDS            USD-LIBOR                               37495
# AUD-BBR-BBSW                 USD-SOFR-COMPOUND                       33895
# USD-SOFR-COMPOUND            USD-FEDERAL FUNDS-H.15-OIS-COMPOUND     33069
# CAD-CORRA-OIS COMPOUND       CAD-CDOR                                31132
# CAD-BA-CDOR                  USD-SOFR-COMPOUND                       30644
# USD-SOFR-COMPOUND            EUR-EUROSTR-COMPOUND                    29690
# MXN-TIIE                     USD-SOFR-OIS COMPOUND                   29254
# EUR-EURIBOR-REUTERS          EUR-EUROSTR-COMPOUND                    27418
# NZD-BKBM FRA                 USD-SOFR-OIS COMPOUND                   25895
# JPY-LIBOR-BBA                USD-LIBOR-BBA                           25264
# AUD-AONIA-OIS COMPOUND       AUD-BBSW                                22454
# USD-LIBOR-BBA                GBP-SONIA                               22120
# USD-SOFR-OIS COMPOUND        JPY-TONA-OIS COMPOUND                   18353
# SEK-STIBOR-SIDE              USD-SOFR-COMPOUND                       17983
# Name: notional_1_base, dtype: int64

# %%
final_df.groupby(['exch_date', 'Product ID'])['notional_1_base'].sum().tail(300). \
    unstack().plot(kind='bar', stacked=True, figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='exch_date'>

# %%
final_df.groupby(['exch_date', 'Notional Currency 1'])['notional_1_base'].sum().tail(600). \
    unstack().plot(kind='bar', stacked=True, figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='exch_date'>
